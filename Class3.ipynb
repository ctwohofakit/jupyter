# %% [markdown]
# # Linked Lists
# In general, there are two variteies of *linked Lists*:
# 1. Signly linked lists (or uni-directional lists)
# 2. Doubly linked lists (or bi-directional lists)
#
# # Real array has fixed length myarray[10]=[1,2,3,4]
# # All item in array must be the same data type int array[1,2,3]

# %%
mylist=[]
help(mylist)
# Out:
# Help on list object:
#
# class list(object)
#  |  list(iterable=(), /)
#  |
#  |  Built-in mutable sequence.
#  |
#  |  If no argument is given, the constructor creates a new empty list.
#  |  The argument must be an iterable if specified.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return bool(key in self).
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(self, index, /)
#  |      Return self[index].
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __iadd__(self, value, /)
#  |      Implement self+=value.
#  |
#  |  __imul__(self, value, /)
#  |      Implement self*=value.
#  |
# ...

# %%
class SinglyLinkedList():
    class __Node:
        def __init__(self, datum):
            self.datum=datum
            self.next=None

    def __init__(self):
        self.head=None
        self.tail=None

    def append(self, value):
        #Adds a new node at the tail of our list O(1)
        new_node=self.__Node()
        if not self.head:
            self.front=self.tail=new_node
        else:
            self.tail.next=new_node
            self.tail=new_node


    def insert(self, index, value):
        #O(n) ,if it is tail 
        #We replace the head node, we can add anywhere in the middle of the list, or we can append, with this method
        new_node=self.__Node()
        if not self.head:
            self.front=self.tail=new_node
        elif index==0:
            new_node=self.head
            self.head=new_node
        else:
            prev=None         #prev point to nothing
            current=self.head #current point to head
            found = False     #preset found is untrue
            count=0 
            while current.next and not found: #preset found is untrue
                if count==index:
                    found=True
                else:
                    prev=currnt
                    current=current.next
                    count +=1
                if found:
                    prev.next=new_node
                    new_node.next=current
                else:
                    current.next=new_node
                    self.tail=new_node
            


    def remove(self, value):
        #remove the first instance of "value" from the list.
        if self.head:
            current=self.head
            prev=None
            found=False
            while current and not found: #As long as current is not None and found continues to be Trues
                if current.datum ==value:
                    found =True
                else:
                    prev=current
                    current=current.next
            if found:
                if not prev:
                    self.head=self.head.next
                    if not self.head:
                        self.tail=None
                else:
                    prev.next=current.next
            else: ValueError("value not found")
        else:
            raise IndexError("List empty")
            
        


    def index(self, value):
        count = 0
        current = self.head
        while current:
            if current.datum == value:
                return count
            current = current.next
            count += 1
        raise ValueError("value not found")


    
    def __len__(self):
        count=0
        current=self.head
        while current:
            count+=1
            current =current.next
        return count


    def __str__(self):
        out = "["
        current = self.head
        if current:
            out += "%s" % current.datum
            current = current.next  # Move to the next node after printing the first datum
            while current:
                out += ", %s" % current.datum
                current = current.next
        out += "]"
        return out



    def __getitem__(self, index):
        count=0
        current=self.head
        while current:
            if count==index:
                return current.datum
            current=current.next
            count+=1
        raise IndexError("Index out of range")
        # Allow us to access a specific index in the list, IE through: mylist[2]

# %%
# Homework: Get to the same point, with "DoublyLinkedList" by next class, meaning: implement at least append and insert.

# %%
class DoublyLinkedList():
    class __Node:
        def __init__(self, datum):
            self.datum=datum
            self.prev=None
            self.next=None

    def __init__(self):
        self.head=None
        self.tail=None

    def append(self, value):
        new_node=self.__Node(value)
        if not self.head:                   #if no head node, create a new node that is represent the head,also is the tail as the new node
            self.head=self.tail=new_node
        else:
            self.tail=new_node
            new_node.prev=self.tail
            self.tail.next=new_node
            

    def insert(self, index, value):
# 1. If empty list:
        new_node = self.__Node(value)
        if not self.head:
            self.head = self.tail = new_node
            return
    
# 2. If inserting at the beginning:
        if index <= 0:
            new_node.next = self.head
            self.head.prev = new_node
            self.head = new_node
            return
    
# 3. Inserting in the middle: find the insertion point.
        prev = None         # prev initially points to nothing.
        current = self.head # current starts at the head.
        found = False       # preset found flag to False.
        count = 0 
        while current and not found:  # Traverse until we either run out of nodes or reach the target index.
            if count == index:
                found = True
            else:
                prev = current
                current = current.next
                count += 1
    
        if found:
         # Insert before the current node.
            new_node.next = current
            new_node.prev = prev
            if prev:
                prev.next = new_node
            current.prev = new_node
        else:
 # 4. If not found, insert at hte end.
            new_node.prev = self.tail
            self.tail.next = new_node
            self.tail = new_node



    
    def remove(self, value):
        #remove the first instance of "value" from the list.
        if self.head:
            current=self.head
            prev=None
            found=False
            while current and not found: #As long as current is not None and found continues to be Trues
                if current.datum ==value:
                    found =True
                else:
                    prev=current
                    current=current.next
            if found:
                if not prev:
                    self.head=self.head.next
                    if not self.head:
                        self.tail=None
                else:
                    prev.next=current.next
                    if current.next is None:
                        self.tail=prev
            else: ValueError("value not found")
        else:
            raise IndexError("List empty")

    def index(self, value):
        count = 0
        current = self.head
        while current:
            if current.datum == value:
                return count
            current = current.next
            count += 1
        raise ValueError("value not found")

    def __len__(self):
        count=0
        current=self.head
        while current:
            count+=1
            current =current.next
        return count
        
    def __getitem__(self, index):
        count=0
        current=self.head
        while current:
            if count==index:
                return current.datum
            current=current.next
            count+=1
        raise IndexError("Index out of range")
